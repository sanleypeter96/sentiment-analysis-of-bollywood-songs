# %% [markdown]
# # Importing packages

# %%
import os
import io
import sklearn
import nltk
import re
import string
from nltk.tokenize import word_tokenize
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score

# %% [markdown]
# # DATA PRE PROCESSING

# %%
df_cleaned = pd.read_csv("lyrics_1051_cleaned.csv", index_col=[0], encoding='utf-8')

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
df_cleaned = df_cleaned.drop('X', 1)
# Out:
# /var/folders/b4/nkxf6pt52pg709ctszrm1ygm0000gn/T/ipykernel_49536/3861854409.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_cleaned = df_cleaned.drop('X', 1)

# %%
temp = df_cleaned

# %%
temp["lyrics"]=temp["lyrics"].apply(str)

# %%
temp = temp.dropna().reset_index(drop=True)

# %%
temp.shape
# Out:
# (1051, 6)

# %% [markdown]
# ## Cleaning the Hindi lyrics

# %%
temp["hin_cleaned"] = temp["lyrics"].map(lambda x: re.sub(r'\\xa\d', '', x))
temp["hin_cleaned"] = temp["hin_cleaned"].map(lambda x: re.sub(r'[\.]+', '', x))
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'\s*x\s*[0-9]', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'\s+', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[,]+', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[?]+', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'\s+x\s+[०१२३४५६७८९]', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[)()]', ' ', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))
temp["hin_cleaned"] = temp["hin_cleaned"].map(lambda x: re.sub(r'\d*', '', x))
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'\t+', '', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[’]+', '', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[“]+', '', regex=True) 
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[”]+', '', regex=True)
temp["hin_cleaned"] = temp["hin_cleaned"].replace(r'[A-Za-z]+', '', regex=True)

# %% [markdown]
# ## Cleaning translated english lyrics

# %%
temp["eng_cleaned"]=temp["eng_cleaned"].apply(str)

# %%
temp["eng_cleaned"] = temp["eng_cleaned"].map(lambda x: re.sub(r'\\xa\d', '', x))
temp["eng_cleaned"] = temp["eng_cleaned"].map(lambda x: re.sub(r'[\.]+', '.', x))
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'\s*X\s*[0-9]', ' ', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'\s*x\s*[0-9]', ' ', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'\s+', ' ', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))
temp["eng_cleaned"] = temp["eng_cleaned"].map(lambda x: re.sub(r'\d*', '', x))
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'\t+', '', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'[’]+', '', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'[“]+', '', regex=True) 
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'[”]+', '', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'\\n', '', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'[)()]', '', regex=True)
temp["eng_cleaned"] = temp["eng_cleaned"].replace(r'ॐ', '', regex=True)

# %%
temp.drop(temp[temp['Title'] == "tu-jo-mila-reprise-hindi"].index, inplace=True)    # manually found out and removed the duplicate

# %%
temp.drop(temp[temp['Title'] == "ramleela-movie"].index, inplace=True)    # manually found out that it did not contain song lyrics but movie dialogs and hence removed this row

# %% [markdown]
# ## Write final dataset to csv for using in other models

# %%
temp.to_csv("lyrics_1051_cleaned.csv", encoding="utf-8")

# %% [markdown]
# # Hindi SentiwordNet approach

# %% [markdown]
# The development of the below model is referenced from the github source https://github.com/shubham721/Sentiment-Analysis-On-Hindi-Reviews

# %% [markdown]
# ## Removing hindi stop words

# %%
stopwords_hindi = open('final_stopwords.txt','r').read().splitlines()

# %%
def remove_stopwords(text):
  '''
  this method removes the stop words in a given text using the stopwords_hindi specified.
  '''
  return " ".join([word for word in text.split() if word not in stopwords_hindi])

# %%
temp['hin_cleaned'] = temp.hin_cleaned.apply(remove_stopwords)

# %%
temp['hin_cleaned']
# Out:
# 0       लोगो दुनिया हर कदम इंसा गलत सही समझ के कहु गलत...
# 1       छल्ली दे सीना दाग दे सारी गोलियाँ नी अज्ज जी क...
# 2       पिया तू काहें रूठा रे निगोड़ा जग झूठा रे पिया त...
# 3       आरम्भ प्रचण्ड बोले मस्तकों के झुंड ज़ंग घड़ी ग...
# 4       सर उठेगा धड़ कटेगा छिपेगा बचेगा पथ पथ घाट मौत क...
#                               ...
# 1046    दिन मोहब्बत ओढ़ दिन गली मोड़ तेरी हथेली परलिखूं ...
# 1047    ज़िन्दगी सफ़र कैसा सफ़र समझा नहीं जाना नहीं ज़...
# 1048    ज़िन्दगी के सफ़र गुज़र मकाम वो नहीं आते वो नही...
# 1049    ज़िन्दगी मौत ना बन जाए संभालो यारों खो चैनओअमन...
# 1050    गुनगुनाती हवाएं गुनगुनाती गगन गा सार आलम ज़ूबी...
# Name: hin_cleaned, Length: 1050, dtype: object

# %% [markdown]
# ### Load the Hindi-SentiWordNet and implement Sentiment Analysis

# %%
data = pd.read_csv("HindiSentiWordnet.txt", delimiter=' ')

# %%
fields = ['POS_TAG', 'ID', 'POS', 'NEG', 'LIST_OF_WORDS']

# %%
words_dict = {}
for i in data.index:
    words = data[fields[4]][i].split(',')
    for word in words:
        words_dict[word] = (data[fields[0]][i], data[fields[2]][i], data[fields[3]][i])

# %%
words_dict
# Out:
# {'अनौपचारिक': ('a', 0.0, 0.0),
#  'मृत': ('a', 0.0, 0.75),
#  'परवर्ती': ('a', 0.125, 0.0),
#  'अच्छा': ('a', 0.75, 0.0),
#  'बढ़िया': ('a', 0.625, 0.0),
#  'सौभाग्यशाली': ('a', 0.875, 0.0),
#  'खुशकिस्मत': ('a', 0.875, 0.0),
#  'खुशनसीब': ('a', 0.875, 0.0),
#  'तक़दीर_वाला': ('a', 0.875, 0.0),
#  'नसीब_वाला': ('a', 0.875, 0.0),
#  'भाग्यवान': ('a', 0.875, 0.0),
#  'भाग्यशाली': ('a', 0.875, 0.0),
#  'ख़ुशक़िस्मत': ('a', 0.875, 0.0),
#  'ख़ुशनसीब': ('a', 0.875, 0.0),
#  'दुर्भाग्यशाली': ('a', 0.0, 1.0),
#  'अभागा': ('a', 0.0, 1.0),
#  'बदनसीब': ('a', 0.0, 1.0),
#  'भाग्यहीन': ('a', 0.0, 1.0),
#  'मनहूस': ('a', 0.0, 1.0),
#  'बदकिस्मत': ('a', 0.0, 1.0),
#  'मंदभाग्य': ('a', 0.0, 1.0),
#  'बदक़िस्मत': ('a', 0.0, 1.0),
#  'दईमारा': ('a', 0.0, 1.0),
#  'कमबख्त': ('a', 0.0, 1.0),
#  'कमबख़्त': ('a', 0.0, 1.0),
#  'अधन्य': ('a', 0.0, 1.0),
#  'अभागी': ('a', 0.0, 1.0),
#  'आवासहीन': ('a', 0.0, 0.875),
#  'आश्रयहीन': ('a', 0.125, 0.375),
#  'गृहहीन': ('a', 0.0, 0.875),
#  'गृहविहीन': ('a', 0.0, 0.875),
#  'बेघर': ('a', 0.0, 0.875),
#  'बेघरबार': ('a', 0.0, 0.875),
#  'अगतिक': ('a', 0.0, 0.875),
#  'अगेह': ('a', 0.0, 0.875),
#  'अनिकेत': ('a', 0.0, 0.875),
#  'सुगंधित': ('a', 0.25, 0.125),
#  'सुगन्धित': ('a', 0.25, 0.125),
#  'ख़ुशबूदार': ('a', 0.25, 0.125),
#  'सुगंधपूर्ण': ('a', 0.25, 0.125),
#  'सुरभित': ('a', 0.25, 0.125),
#  'अधिवासित': ('a', 0.25, 0.125),
#  'खुशबूदार': ('a', 0.25, 0.125),
#  'बदबूदार': ('a', 0.0, 0.75),
#  'दुर्गंधपूर्ण': ('a', 0.0, 0.75),
#  'दुर्गंधयुक्त': ('a', 0.0, 0.75),
#  'दुर्गंधित': ('a', 0.0, 0.75),
#  'लगा': ('a', 0.0, 0.0),
#  'लगा_हुआ': ('a', 0.0, 0.0),
#  'ढीला': ('a', 0.0, 0.375),
#  'अश्लिष्ट': ('a', 0.125, 0.5),
#  'असंयुक्त': ('a', 0.125, 0.5),
#  'असंयोजित': ('a', 0.125, 0.5),
#  'असंबद्ध': ('a', 0.0, 0.625),
#  'अलग': ('r', 0.0, 0.0),
#  'अजुड़ा': ('a', 0.125, 0.5),
#  'अजोड़': ('v', 0.0, 0.0),
#  'पृथक्': ('a', 0.125, 0.5),
#  'जुदा': ('a', 0.125, 0.5),
#  'पृथक': ('a', 0.125, 0.5),
#  'अपृक्त': ('n', 0.0, 0.0),
#  'पराधीन': ('a', 0.0, 0.75),
#  'गुलाम': ('n', 0.0, 0.0),
#  'परतंत्र': ('a', 0.0, 0.75),
#  'अन्याधीन': ('a', 0.0, 0.75),
#  'अपरवश': ('a', 0.0, 0.75),
#  'परवश': ('a', 0.0, 0.75),
#  'अवश': ('a', 0.0, 0.5),
#  'अबस': ('a', 0.0, 0.5),
#  'अधिकतः': ('a', 0.0, 0.0),
#  'अधिकांशतः': ('a', 0.0, 0.0),
#  'प्रायः': ('a', 0.0, 0.0),
#  'ताज़ा': ('a', 0.5, 0.375),
#  'ताजा': ('a', 0.5, 0.375),
#  'अम्लान': ('a', 0.5, 0.375),
#  'बासी': ('a', 0.5, 0.25),
#  'बसिया': ('a', 0.5, 0.25),
#  'कठिनाई_से': ('r', 0.125, 0.25),
#  'जैसे_तैसे': ('r', 0.125, 0.25),
#  'मुश्किल_से': ('r', 0.125, 0.25),
#  'कठिनतः': ('r', 0.125, 0.25),
#  'सड़ा': ('a', 0.0, 0.875),
#  'जड़': ('a', 0.0, 0.125),
#  'अचैतन्य': ('a', 0.0, 0.625),
#  'जड़त्वयुक्त': ('a', 0.0, 0.625),
#  'स्थूल': ('a', 0.0, 0.625),
#  'अजैव': ('a', 0.0, 0.625),
#  'भौतिक': ('a', 0.0, 0.625),
#  'अचेतन': ('a', 0.0, 0.625),
#  'चेतनारहित': ('a', 0.0, 0.625),
#  'अजीव': ('a', 0.0, 0.625),
#  'अनात्म': ('a', 0.0, 0.625),
#  'आत्मारहित': ('a', 0.0, 0.625),
#  'हत': ('a', 0.0, 0.25),
#  'वधित': ('a', 0.0, 0.25),
#  'मक़तूल': ('a', 0.0, 0.25),
#  'दोस्ताना': ('a', 0.125, 0.25),
#  'मित्रवत': ('a', 0.125, 0.25),
#  'मित्रतापूर्ण': ('a', 0.125, 0.25),
#  'मित्रोचित': ('a', 0.125, 0.25),
#  'मैत्रीपूर्ण': ('a', 0.125, 0.25),
#  'मृतजात': ('a', 0.25, 0.5),
#  'बर्फीला': ('a', 0.0, 0.0),
#  'बर्फानी': ('a', 0.0, 0.0),
#  'बर्फ़ानी': ('a', 0.0, 0.0),
#  'बर्फ़ीला': ('a', 0.0, 0.0),
#  'बरफीला': ('a', 0.0, 0.0),
#  'बरफानी': ('a', 0.0, 0.0),
#  'बरफ़ानी': ('a', 0.0, 0.0),
#  'बरफ़ीला': ('a', 0.0, 0.0),
#  'हिमयुक्त': ('a', 0.0, 0.0),
#  'फलदार': ('a', 0.5, 0.125),
#  'फलद': ('a', 0.5, 0.125),
#  'फलदायी': ('a', 0.5, 0.125),
#  'फलदायक': ('a', 0.5, 0.125),
#  'अफल': ('a', 0.0, 0.5),
#  'अफलित': ('a', 0.0, 0.5),
#  'फलहीन': ('a', 0.0, 0.875),
#  'फलरहित': ('a', 0.0, 0.5),
#  'फलविहीन': ('a', 0.0, 0.875),
#  'असफल': ('a', 0.0, 0.5),
#  'नाकामयाब': ('a', 0.0, 0.25),
#  'विफल': ('a', 0.0, 0.5),
#  'नाकाम': ('a', 0.0, 0.5),
#  'निष्फल': ('a', 0.0, 0.5),
#  'निस्संतान': ('a', 0.0, 0.625),
#  'निःसंतान': ('a', 0.0, 0.625),
#  'बेऔलाद': ('a', 0.0, 0.625),
#  'संतानहीन': ('a', 0.0, 0.625),
#  'संतानरहित': ('a', 0.0, 0.625),
#  'अऊत': ('a', 0.0, 0.625),
#  'अनपत्य': ('a', 0.0, 0.625),
#  'भली-भाँति': ('a', 0.0, 0.375),
#  'भली_भाँति': ('a', 0.0, 0.375),
#  'भरपूर': ('a', 0.0, 0.375),
#  'भलीभाँति': ('a', 0.0, 0.375),
#  'भली-भांति': ('a', 0.0, 0.375),
#  'भली_भांति': ('a', 0.0, 0.375),
#  'भलीभांति': ('a', 0.0, 0.375),
#  'रिक्त': ('v', 0.0, 0.0),
#  'ख़ाली': ('v', 0.0, 0.0),
#  'खाली': ('v', 0.0, 0.0),
#  'रीता': ('v', 0.0, 0.0),
#  'शून्य': ('n', 0.0, 0.0),
#  'संरचनात्मक': ('a', 0.0, 0.0),
#  'चटोरा': ('a', 0.0, 0.0),
#  'स्वादलोलुप': ('a', 0.0, 0.0),
#  'चटोर': ('a', 0.0, 0.0),
#  'पंखहीन': ('a', 0.0, 0.5),
#  'पक्षरहित': ('a', 0.0, 0.5),
#  'अपक्ष': ('a', 0.0, 0.5),
#  'अपच्छी': ('a', 0.0, 0.5),
#  'अपत्र': ('a', 0.0, 0.0),
#  'धड़कना': ('v', 0.0, 0.0),
#  'स्पंदित_होना': ('v', 0.0, 0.0),
#  'अतकनीकी': ('a', 0.0, 0.75),
#  'ग़ैरतकनीकी': ('a', 0.0, 0.75),
#  'गैरतकनीकी': ('a', 0.0, 0.75),
#  'तकनीकहीन': ('a', 0.0, 0.75),
#  'प्राविधिहीन': ('a', 0.0, 0.75),
#  'उदार': ('a', 0.375, 0.0),
#  'विशालहृदय': ('a', 0.375, 0.0),
#  'उदारचरित': ('a', 0.375, 0.0),
#  'उदारचेता': ('a', 0.375, 0.0),
#  'दरियादिल': ('a', 0.375, 0.0),
#  'उदरचित्त': ('a', 0.375, 0.0),
#  'उदारमना': ('a', 0.375, 0.0),
#  'अकृपण': ('a', 0.375, 0.0),
#  'निरोगता': ('a', 0.625, 0.0),
#  'आरोग्यता': ('a', 0.625, 0.0),
#  'स्वस्थता': ('a', 0.625, 0.0),
#  'सेहतमंदी': ('a', 0.625, 0.0),
#  'अनामय': ('a', 0.75, 0.0),
#  'तंदुरुस्ती': ('a', 0.625, 0.0),
#  'दुर्गुणी': ('a', 0.0, 0.5),
#  'अगुणी': ('a', 0.0, 0.5),
#  'अपगुणी': ('a', 0.0, 0.5),
#  'ऐबी': ('a', 0.0, 0.5),
#  'खोटा': ('a', 0.0, 0.5),
#  'विपरीत': ('a', 0.125, 0.0),
#  'प्रतिकूल': ('a', 0.0, 0.625),
#  'खिलाफ': ('a', 0.0, 0.625),
#  'ख़िलाफ़': ('a', 0.0, 0.625),
#  'विरुद्ध': ('a', 0.125, 0.0),
#  'प्रतीप': ('a', 0.125, 0.0),
#  'महत्वाकांक्षी': ('a', 0.375, 0.125),
#  'उच्चाकांक्षी': ('a', 0.375, 0.125),
#  'बुलंदपरवाज़': ('a', 0.375, 0.125),
#  'सज्जन': ('a', 0.375, 0.125),
#  'भद्र': ('a', 1.0, 0.0),
#  'भला': ('a', 0.375, 0.125),
#  'शरीफ़': ('a', 0.375, 0.125),
#  'शीलवान': ('a', 0.375, 0.125),
#  'सद्गुणी': ('a', 0.375, 0.125),
#  'नेक': ('a', 0.375, 0.125),
#  'सुप्रतीक': ('a', 0.75, 0.0),
#  'शरीफ': ('a', 0.375, 0.125),
#  'कुस्वभावी': ('a', 0.0, 0.75),
#  'कुबुद्धि': ('a', 0.0, 0.75),
#  'दुश्शील': ('a', 0.0, 0.75),
#  'बदमिज़ाज': ('a', 0.0, 0.75),
#  'बदमिजाज': ('a', 0.0, 0.75),
#  'सहज': ('a', 0.125, 0.5),
#  'प्रवाहित': ('a', 0.25, 0.0),
#  'बहता': ('a', 0.25, 0.0),
#  'बहता_हुआ': ('a', 0.25, 0.0),
#  'प्रवाहशील': ('a', 0.25, 0.0),
#  'प्रवाहमय': ('a', 0.25, 0.0),
#  'गतिशील': ('a', 0.25, 0.0),
#  'गतिमान': ('a', 0.25, 0.0),
#  'प्रवाही': ('a', 0.25, 0.0),
#  'अनपेक्षित': ('a', 0.0, 0.5),
#  'अप्रत्याशित': ('a', 0.0, 0.0),
#  'निरपेक्षित': ('a', 0.0, 0.0),
#  'ढलवाँ': ('n', 0.0, 0.0),
#  'ढलुवाँ': ('n', 0.0, 0.0),
#  'ढालवाँ': ('n', 0.0, 0.0),
#  'ढालू': ('n', 0.0, 0.0),
#  'ढलुआ': ('n', 0.0, 0.0),
#  'ढलाऊ': ('a', 0.0, 0.0),
#  'उतारू': ('n', 0.0, 0.0),
#  'निकम्मा': ('a', 0.125, 0.625),
#  'निठल्ला': ('a', 0.125, 0.625),
#  'अकर्मण्य': ('a', 0.125, 0.625),
#  'निखट्टू': ('a', 0.125, 0.625),
#  'अनेरा': ('a', 0.125, 0.625),
#  'बेकार': ('a', 0.0, 0.75),
#  'फालतू': ('a', 0.0, 0.75),
#  'गायताल': ('a', 0.125, 0.625),
#  'अकर्मा': ('a', 0.125, 0.625),
#  'नालायक': ('a', 0.0, 0.875),
#  'ना-लायक': ('a', 0.0, 0.875),
#  'अनलायक': ('a', 0.0, 0.875),
#  'बेकदर': ('a', 0.0, 0.625),
#  'बेक़दर': ('a', 0.0, 0.625),
#  'बेक़द्र': ('a', 0.0, 0.625),
#  'बेकद्र': ('a', 0.0, 0.625),
#  'फौलादी': ('a', 0.125, 0.375),
#  'इस्पाती': ('a', 0.125, 0.375),
#  'फ़ौलादी': ('a', 0.125, 0.375),
#  'इसपाती': ('a', 0.125, 0.375),
#  'कंठ्य': ('a', 0.0, 0.0),
#  'कठोरहृदय': ('a', 0.0, 0.75),
#  'कठोर_हृदय': ('a', 0.0, 0.75),
#  'पत्थरदिल': ('a', 0.0, 0.75),
#  'संगदिल': ('a', 0.0, 0.75),
#  'पाषाण_हृदय': ('a', 0.0, 0.75),
#  'मादक': ('a', 0.0, 0.0),
#  'नशीला': ('a', 0.0, 0.0),
#  'नशेदार': ('a', 0.0, 0.0),
#  'हानिकारक': ('a', 0.125, 0.75),
#  'क्षतिकारी': ('a', 0.125, 0.75),
#  'हानिकर': ('a', 0.125, 0.75),
#  'नुक़सानदेह': ('a', 0.125, 0.75),
#  'नुकसानदेह': ('a', 0.125, 0.75),
#  'हानिप्रद': ('a', 0.125, 0.75),
#  'अनर्थकारी': ('a', 0.125, 0.75),
#  'क्षतिकर': ('a', 0.125, 0.75),
#  'अपमानजनक': ('a', 0.0, 0.875),
#  'कुमारी': ('a', 0.375, 0.0),
#  'कुँआरी': ('a', 0.375, 0.0),
#  'कुमारिका': ('a', 0.375, 0.0),
#  'कुँवारी': ('a', 0.375, 0.0),
#  'क्वाँरी': ('a', 0.375, 0.0),
#  'कुंवारी': ('a', 0.375, 0.0),
#  'कँवारी': ('a', 0.375, 0.0),
#  'जंतु': ('a', 0.0, 0.0),
#  'जन्तु': ('a', 0.0, 0.0),
#  'प्राणी': ('a', 0.0, 0.0),
#  'जीव': ('a', 0.0, 0.0),
#  'जानवर': ('n', 0.0, 0.0),
#  'जीवधारी': ('a', 0.125, 0.0),
#  'जानदार': ('a', 0.75, 0.0),
#  'स्वस्थ': ('a', 0.75, 0.0),
#  'निरोग': ('a', 0.75, 0.0),
#  'नीरोग': ('a', 0.75, 0.0),
#  'तंदुरुस्त': ('a', 0.75, 0.0),
#  'सेहतमंद': ('a', 0.75, 0.0),
#  'भला-चंगा': ('a', 0.75, 0.0),
#  'व्याधिहीन': ('a', 0.75, 0.0),
#  'रोगहीन': ('a', 0.75, 0.0),
#  'आरोग्य': ('a', 0.75, 0.0),
#  'चंगा': ('a', 0.75, 0.0),
#  'बहाल': ('a', 0.75, 0.0),
#  'निरामय': ('a', 0.75, 0.0),
#  'अगद': ('a', 0.75, 0.0),
#  'अभुग्न': ('a', 0.75, 0.0),
#  'स्वर्गीय': ('a', 0.125, 0.0),
#  'स्वर्गिक': ('a', 0.125, 0.0),
#  'दिव्य': ('a', 0.125, 0.0),
#  'वैकुंठीय': ('a', 0.125, 0.0),
#  'स्वर्गी': ('a', 0.125, 0.0),
#  'बहिश्ती': ('a', 0.125, 0.0),
#  'बिहिश्ती': ('a', 0.125, 0.0),
#  'अभी_भी': ('r', 0.125, 0.25),
#  'अब': ('r', 0.0, 0.0),
#  'अबकी': ('r', 0.0, 0.0),
#  'इसबार': ('r', 0.0, 0.0),
#  'अब_की': ('r', 0.0, 0.0),
#  'इस_बार': ('r', 0.0, 0.0),
#  'अभी-अभी': ('r', 0.0, 0.0),
#  'अभी_अभी': ('r', 0.0, 0.0),
#  'अभी_ही': ('r', 0.0, 0.0),
#  'इसी_वक्त': ('r', 0.0, 0.0),
#  'इसी_क्षण': ('r', 0.0, 0.0),
#  'दयापूर्वक': ('r', 0.375, 0.0),
#  'कृपा_कर_के': ('r', 0.375, 0.0),
#  'कृपापूर्वक': ('r', 0.375, 0.0),
#  'दया_से': ('r', 0.375, 0.0),
#  'बराए_मेहरबानी': ('r', 0.375, 0.0),
#  'गूदेदार': ('a', 0.0, 0.5),
#  'आत्म_विषयक': ('a', 0.375, 0.125),
#  'आत्मा_विषयक': ('a', 0.375, 0.125),
#  'अध्यात्म': ('a', 0.375, 0.125),
#  'आत्मिक': ('a', 0.375, 0.125),
#  'रूहानी': ('a', 0.0, 0.375),
#  'सैद्धांतिक': ('a', 0.125, 0.125),
#  'सिद्धांतीय': ('a', 0.125, 0.125),
#  'रक्तहीन': ('a', 0.375, 0.25),
#  'श्रेयस्कर': ('a', 0.5, 0.0),
#  'अनुकरणीय': ('a', 0.5, 0.125),
#  'सत्कृत': ('a', 0.625, 0.0),
#  'आदृत': ('a', 0.625, 0.0),
#  'सत्कार_कृत': ('a', 0.625, 0.0),
#  'उल्लेखनीय': ('a', 0.375, 0.0),
#  'उल्लेख्य': ('a', 0.375, 0.0),
#  'निंदनीय': ('a', 0.0, 0.0),
#  'निन्दनीय': ('a', 0.0, 0.0),
#  'निद्य': ('a', 0.0, 0.0),
#  'निंदात्मक': ('a', 0.0, 0.0),
#  'दुविधाहीन': ('r', 0.0, 0.0),
#  'दुबिधाहीन': ('r', 0.0, 0.0),
#  'संदेहहीन': ('a', 0.0, 0.625),
#  'संशयहीन': ('a', 0.125, 0.5),
#  'परे': ('r', 0.0, 0.0),
#  'आगे': ('r', 0.0, 0.0),
#  'बाद': ('r', 0.0, 0.0),
#  'फिलहाल': ('r', 0.0, 0.0),
#  'फ़िलहाल': ('r', 0.0, 0.0),
#  'वर्तमान_में': ('r', 0.0, 0.0),
#  'आज-कल': ('r', 0.0, 0.0),
#  'आजकल': ('r', 0.0, 0.0),
#  'आज_कल': ('r', 0.0, 0.0),
#  'इन_दिनों': ('r', 0.0, 0.0),
#  'इस_समय': ('r', 0.0, 0.0),
#  'संप्रति': ('r', 0.0, 0.0),
#  'अप्रसन्नतापूर्वक': ('r', 0.0, 0.5),
#  'नाराज़गीपूर्वक': ('r', 0.0, 0.5),
#  'नाख़ुशी_से': ('r', 0.0, 0.5),
#  'नाराजगीपूर्वक': ('r', 0.0, 0.5),
#  'नाखुशी_से': ('r', 0.0, 0.5),
#  'स्वतः': ('r', 0.375, 0.0),
#  'अपनेआप': ('r', 0.375, 0.0),
#  'ख़ुद-ब-ख़ुद': ('r', 0.375, 0.0),
#  'ख़ुदबख़ुद': ('r', 0.375, 0.0),
#  'खुद-ब-खुद': ('r', 0.375, 0.0),
#  'खुदबखुद': ('r', 0.375, 0.0),
#  'अतिशीघ्र': ('r', 0.0, 0.0),
#  'अतिशीघ्रतः': ('r', 0.0, 0.0),
#  'जल्द_से_जल्द': ('r', 0.0, 0.0),
#  'जल्दी_से_जल्दी': ('r', 0.0, 0.0),
#  'खुलेआम': ('a', 0.0, 0.0),
#  'खुलकर': ('a', 0.0, 0.0),
#  'सरेआम': ('a', 0.0, 0.0),
#  'सरे-आम': ('a', 0.0, 0.0),
#  'खुले-आम': ('a', 0.0, 0.0),
#  'खुल्लम-खुल्ला': ('a', 0.0, 0.0),
#  'खुल्लमखुल्ला': ('a', 0.0, 0.0),
#  'डंके_की_चोट_पर': ('a', 0.0, 0.0),
#  'सरे_आम': ('a', 0.0, 0.0),
#  'अगुप्ततः': ('a', 0.0, 0.0),
#  'बहुत': ('a', 0.0, 0.125),
#  'अधिक': ('a', 0.0, 0.125),
#  'ज्यादा': ('a', 0.0, 0.125),
#  'ज़्यादा': ('a', 0.0, 0.125),
#  'ख़ूब': ('a', 0.0, 0.125),
#  'खूब': ('a', 0.0, 0.125),
#  'अतिशय': ('a', 0.0, 0.125),
#  'अति': ('a', 0.0, 0.125),
#  'अगाध': ('a', 0.0, 0.125),
#  'अतीव': ('a', 0.0, 0.125),
#  'काफ़ी': ('a', 0.0, 0.125),
#  'काफी': ('a', 0.0, 0.125),
#  'अंबोह': ('a', 0.0, 0.125),
#  'अनल्प': ('a', 0.0, 0.125),
#  'अनून': ('a', 0.0, 0.125),
#  'अन्यून': ('a', 0.0, 0.125),
#  'अबेश': ('a', 0.0, 0.125),
#  'अग्रतः': ('r', 0.0, 0.0),
#  'पास_में': ('r', 0.125, 0.75),
#  'नज़दीक': ('r', 0.125, 0.75),
#  'नजदीक': ('r', 0.125, 0.75),
#  'निकट_में': ('r', 0.125, 0.75),
#  'क़रीब_में': ('r', 0.125, 0.75),
#  'समीप': ('r', 0.125, 0.75),
#  'निकट': ('r', 0.125, 0.75),
#  'पास': ('a', 0.0, 0.0),
#  'क़रीब': ('r', 0.125, 0.75),
#  'करीब': ('r', 0.125, 0.75),
#  'सन्निकट': ('a', 0.125, 0.5),
#  'पूर्व_काल_में': ('r', 0.0, 0.125),
#  'पहले': ('r', 0.0, 0.125),
#  'दृश्य': ('n', 0.0, 0.0),
#  'भविष्य_में': ('r', 0.0, 0.0),
#  'भविष्य_काल_में': ('r', 0.0, 0.0),
#  'अगत्या': ('r', 0.0, 0.0),
#  'ऊपर': ('r', 0.0, 0.125),
#  'विस्तारपूर्वक': ('r', 0.375, 0.125),
#  'विस्तार_से': ('r', 0.375, 0.125),
#  'अन्यत्र': ('r', 0.0, 0.0),
#  'कहीं_और': ('r', 0.0, 0.0),
#  'अनत': ('a', 0.125, 0.625),
#  'बंधन': ('a', 0.25, 0.0),
#  'बद्धी': ('a', 0.25, 0.0),
#  'अनुबंध': ('a', 0.25, 0.0),
#  'अनुबन्ध': ('a', 0.25, 0.0),
#  'बन्धन': ('a', 0.25, 0.0),
#  'अलान': ('a', 0.25, 0.0),
#  'आलान': ('a', 0.25, 0.0),
#  'लगातार': ('a', 0.0, 0.0),
#  'अनवरत': ('a', 0.0, 0.0),
#  'निरंतर': ('r', 0.0, 0.0),
#  'निरन्तर': ('r', 0.0, 0.0),
#  'ताबड़तोड़': ('r', 0.0, 0.0),
#  'दनादन': ('r', 0.0, 0.0),
#  'सतत': ('r', 0.0, 0.0),
#  'धूआँधार': ('r', 0.0, 0.0),
#  'अनंतर': ('a', 0.0, 0.0),
#  'अनन्तर': ('a', 0.0, 0.0),
#  'अनिश': ('r', 0.0, 0.0),
#  'प्रतिक्षण': ('r', 0.0, 0.0),
#  'अनुक्षण': ('r', 0.0, 0.0),
#  'धड़ाधड़': ('r', 0.0, 0.0),
#  'अविरत': ('a', 0.0, 0.0),
#  'शैक्षिक': ('a', 0.25, 0.0),
#  'तालीमी': ('a', 0.0, 0.625),
#  'इल्मी': ('a', 0.0, 0.625),
#  'परिवर्तन_करना': ('v', 0.125, 0.0),
#  'बदलना': ('v', 0.125, 0.0),
#  'बदल_देना': ('v', 0.125, 0.0),
#  'छोड़ना': ('v', 0.0, 0.0),
#  'त्यागना': ('v', 0.0, 0.0),
#  'सुपाच्य': ('v', 0.0, 0.0),
#  'सहज_पाच्य': ('v', 0.0, 0.0),
#  'हलका': ('a', 0.0, 0.0),
#  'हल्का': ('a', 0.125, 0.25),
#  'पथ्य': ('v', 0.0, 0.0),
#  'सोचना': ('v', 0.0, 0.375),
#  'विचारना': ('v', 0.0, 0.0),
#  'देखना': ('v', 0.0, 0.0),
#  'सोंचना': ('v', 0.0, 0.375),
#  'अनुसंधानना': ('v', 0.0, 0.0),
#  'अनुसन्धानना': ('v', 0.0, 0.0),
#  'पोषित_करना': ('v', 0.0, 0.0),
#  'जीवित_रखना': ('v', 0.0, 0.0),
#  'पालित_करना': ('v', 0.0, 0.0),
#  'अल्बानियाई': ('n', 0.0, 0.0),
#  'अमहैरिक': ('a', 0.0, 0.0),
#  'लाड़_करना': ('v', 0.0, 0.0),
#  'दुलार_करना': ('v', 0.0, 0.0),
#  'दुलारना': ('v', 0.0, 0.0),
#  'प्यार_करना': ('v', 0.0, 0.0),
#  'पकड़ना': ('v', 0.0, 0.0),
#  'थामना': ('v', 0.0, 0.0),
#  'धरना': ('v', 0.0, 0.0),
#  'गहना': ('n', 0.125, 0.125),
#  'ढुलाई': ('n', 0.0, 0.0),
#  'ढोवाई': ('n', 0.0, 0.0),
#  'बटना': ('v', 0.0, 0.0),
#  'ऐंठना': ('v', 0.0, 0.0),
#  'पूरना': ('v', 0.0, 0.0),
#  'भाँजना': ('v', 0.0, 0.0),
#  'बँटना': ('v', 0.0, 0.0),
#  'सहलाना': ('v', 0.125, 0.0),
#  'सोहराना': ('v', 0.125, 0.0),
#  'सुहलाना': ('v', 0.125, 0.0),
#  'सुहराना': ('v', 0.125, 0.0),
#  'पोतना': ('v', 0.0, 0.0),
#  'दबाना': ('v', 0.0, 0.0),
#  'गाड़ना': ('v', 0.0, 0.0),
#  'मिशन': ('n', 0.0, 0.0),
#  'कँधियाना': ('v', 0.0, 0.0),
#  'टकराना': ('v', 0.125, 0.25),
#  'भिड़ाना': ('v', 0.0, 0.0),
#  'धूल': ('v', 0.0, 0.0),
#  'धूलि': ('v', 0.0, 0.0),
#  'धूर्रा': ('v', 0.0, 0.0),
#  'रज': ('v', 0.0, 0.0),
#  'गर्द': ('v', 0.0, 0.0),
#  'गुबार': ('v', 0.0, 0.0),
#  'रेणुका': ('v', 0.0, 0.0),
#  'रेतना': ('v', 0.0, 0.0),
#  'रबड़': ('v', 0.0, 0.0),
#  'रबर': ('v', 0.0, 0.0),
#  'नक्काशीदार': ('v', 0.0, 0.0),
#  'नक्क़ाशीदार': ('v', 0.0, 0.0),
#  'उतारना': ('v', 0.0, 0.0),
#  'उधेड़ना': ('v', 0.0, 0.0),
#  'उचाड़ना': ('v', 0.0, 0.0),
#  'मोहर': ('n', 0.0, 0.0),
#  'मुहर': ('n', 0.0, 0.0),
#  'मुद्रा': ('n', 0.0, 0.0),
#  'स्टांप': ('n', 0.0, 0.0),
#  'अंकक': ('n', 0.0, 0.0),
#  'स्टैंप': ('n', 0.0, 0.0),
#  'स्टैम्प': ('n', 0.0, 0.0),
#  'सील': ('n', 0.0, 0.0),
#  'छापा': ('n', 0.0, 0.0),
#  'तह_करना': ('v', 0.0, 0.0),
#  'दुहराना': ('v', 0.0, 0.0),
#  'दोहराना': ('v', 0.0, 0.0),
#  'दोहरा_करना': ('v', 0.0, 0.0),
#  'दुसराना': ('v', 0.0, 0.0),
#  'छानना': ('n', 0.0, 0.0),
#  'छाँदना': ('v', 0.0, 0.0),
#  'प्रेमासक्त': ('a', 0.125, 0.0),
#  'अनुरक्त': ('n', 0.0, 0.0),
#  'अनुरागी': ('a', 0.125, 0.0),
#  'आसक्त': ('a', 0.125, 0.0),
#  'दीवाना': ('a', 0.125, 0.0),
#  'फ़िदा': ('a', 0.0, 0.0),
#  'फिदा': ('a', 0.0, 0.0),
#  'छोही': ('a', 0.125, 0.0),
#  'अनुरागयुक्त': ('a', 0.125, 0.0),
#  'प्रेमयुक्त': ('a', 0.125, 0.0),
#  'अनुरत': ('n', 0.0, 0.0),
#  'अनुशयी': ('a', 0.0, 0.625),
#  'रंजित': ('a', 0.125, 0.0),
#  'रंञ्जित': ('a', 0.125, 0.0),
#  'अभिरंजित': ('a', 0.125, 0.0),
#  'अभिरञ्जित': ('a', 0.125, 0.0),
#  'अनुरंजित': ('a', 0.125, 0.0),
#  'अनुरञ्जित': ('a', 0.125, 0.0),
#  'अभिरत': ('a', 0.125, 0.0),
#  'खोलना': ('v', 0.0, 0.0),
#  'लंगर': ('v', 0.0, 0.0),
#  'लांगल': ('n', 0.0, 0.0),
#  'पंजा': ('n', 0.0, 0.0),
#  'खोजना': ('v', 0.0, 0.0),
#  'खोज_करना': ('v', 0.0, 0.0),
#  'ढूँढ़ना': ('v', 0.0, 0.0),
#  'ढूँढना': ('v', 0.0, 0.0),
#  'तलाशना': ('v', 0.0, 0.0),
#  'पता_लगाना': ('v', 0.0, 0.0),
#  'हत्या': ('n', 0.0, 0.0),
#  'खून': ('n', 0.0, 0.0),
#  'ख़ून': ('n', 0.0, 0.0),
#  'कत्ल': ('n', 0.0, 0.0),
#  'क़त्ल': ('n', 0.0, 0.0),
#  'वध': ('n', 0.0, 0.0),
#  'हनन': ('v', 0.0, 0.0),
#  'घात': ('n', 0.0, 0.0),
#  'अपघात': ('n', 0.0, 0.0),
#  'विघात': ('n', 0.0, 0.0),
#  'सनई': ('v', 0.0, 0.0),
#  'सन': ('n', 0.0, 0.0),
#  'आच्छादित': ('a', 0.0, 0.125),
#  'ढँका': ('a', 0.0, 0.125),
#  'आवृत्त': ('a', 0.0, 0.125),
#  'अपिबद्ध': ('a', 0.0, 0.125),
#  'अपिनद्ध': ('a', 0.0, 0.125),
#  'अपिहित': ('a', 0.0, 0.125),
#  'आच्छन्न': ('a', 0.0, 0.125),
#  'मढ़ना': ('v', 0.0, 0.0),
#  'खपड़ा': ('v', 0.0, 0.5),
#  'खपरा': ('v', 0.0, 0.5),
#  'खपड़ैल': ('v', 0.0, 0.5),
#  'खपरैल': ('v', 0.0, 0.5),
#  'खप्पर': ('v', 0.0, 0.5),
#  'खप्पड़': ('v', 0.0, 0.5),
#  'टाइल': ('v', 0.0, 0.5),
#  'टॉइल': ('v', 0.0, 0.5),
#  'अटकाना': ('v', 0.0, 0.0),
#  'अड़ाना': ('v', 0.0, 0.0),
#  'फँसाना': ('v', 0.0, 0.0),
#  'अड़काना': ('v', 0.0, 0.0),
#  'उलझाना': ('v', 0.0, 0.0),
#  'खुलना': ('v', 0.0, 0.0),
#  'खुल_जाना': ('v', 0.0, 0.0),
#  'उढ़काना': ('v', 0.0, 0.0),
#  'निचोड़ना': ('v', 0.0, 0.0),
#  'गारना': ('v', 0.0, 0.0),
#  'स्क्रू': ('n', 0.0, 0.0),
#  'पेंच': ('n', 0.0, 0.0),
#  'पेच': ('n', 0.0, 0.0),
#  'कुल्फ़ी': ('n', 0.0, 0.0),
#  'कुल्फी': ('n', 0.0, 0.0),
#  'कुलफ़ी': ('n', 0.0, 0.0),
#  'कुलफी': ('n', 0.0, 0.0),
#  'तूमना': ('v', 0.0, 0.0),
#  'गूथना': ('v', 0.0, 0.0),
#  'गूँथना': ('v', 0.0, 0.0),
#  'गूंथना': ('v', 0.0, 0.0),
#  'पिरोना:2': ('v', 0.0, 0.0),
#  'पिरोहना': ('v', 0.0, 0.0),
#  'पोहना': ('v', 0.0, 0.0),
#  'नाधना': ('v', 0.0, 0.0),
#  'नाँधना': ('v', 0.0, 0.0),
#  'दिखावटी': ('a', 0.0, 0.0),
#  'बनावटी': ('a', 0.0, 0.0),
#  'ऊपरी': ('a', 0.0, 0.0),
#  'बनौवा': ('a', 0.0, 0.0),
#  'चढ़ाना': ('v', 0.0, 0.0),
#  'ठुकराना': ('v', 0.0, 0.0),
#  'वर्षा': ('v', 0.0, 0.0),
#  'वृष्टि': ('v', 0.0, 0.0),
#  'उलटना': ('v', 0.0, 0.0),
#  'पलटना': ('v', 0.0, 0.0),
#  'फैलाना': ('v', 0.0, 0.0),
#  'बढ़ाना': ('a', 0.75, 0.0),
#  'प्रसारित_करना': ('v', 0.0, 0.0),
#  'विस्तृत_करना': ('v', 0.0, 0.0),
#  'प्रसार_करना': ('v', 0.0, 0.0),
#  'अरमेनियाई': ('a', 0.0, 0.0),
#  'अर्मेनियाई': ('a', 0.0, 0.0),
#  'अरमेनियन': ('a', 0.0, 0.0),
#  'अर्मेनियन': ('a', 0.0, 0.0),
#  'अरमेनियाई_लिपि': ('a', 0.0, 0.0),
#  'अर्मेनियाई_लिपि': ('a', 0.0, 0.0),
#  'अरमेनियाई-लिपि': ('a', 0.0, 0.0),
#  'अर्मेनियाई-लिपि': ('a', 0.0, 0.0),
#  'मासिक': ('a', 0.0, 0.125),
#  'साप्ताहिक': ('a', 0.125, 0.0),
#  'हफ्तेवार': ('a', 0.125, 0.0),
#  'प्रतिदिन': ('a', 0.0, 0.0),
#  'हरदिन': ('a', 0.0, 0.0),
#  'नित्य': ('r', 0.0, 0.0),
#  'हररोज़': ('a', 0.0, 0.0),
#  'रोज़': ('a', 0.0, 0.0),
#  'नित': ('a', 0.0, 0.0),
#  'रोज': ('a', 0.0, 0.0),
#  'रोज़ाना': ('a', 0.0, 0.0),
#  'रोजाना': ('a', 0.0, 0.0),
#  'अनुदिन': ('a', 0.0, 0.0),
#  'नित्यप्रति': ('a', 0.0, 0.0),
#  'अनुदिवस': ('a', 0.0, 0.0),
#  'लज्जाशील': ('a', 0.375, 0.0),
#  'लजाऊ': ('a', 0.375, 0.0),
#  'झेंपू': ('a', 0.375, 0.0),
#  'लज्जावान': ('a', 0.375, 0.0),
#  'शरमाऊ': ('a', 0.375, 0.0),
#  'शरमीला': ('a', 0.375, 0.0),
#  'शर्मीला': ('a', 0.375, 0.0),
#  'लजालू': ('a', 0.375, 0.0),
#  'लजाधुर': ('a', 0.375, 0.0),
#  'लज्जालु': ('a', 0.375, 0.0),
#  'लजीला': ('a', 0.375, 0.0),
#  'शरमालू': ('a', 0.375, 0.0),
#  'अप्रतिभ': ('a', 0.375, 0.0),
#  'अविलंब': ('v', 0.0, 0.125),
#  'अविलम्ब': ('v', 0.0, 0.125),
#  'बुहारना': ('v', 0.0, 0.0),
#  'झाड़ू_देना': ('v', 0.0, 0.0),
#  'झाड़ू_लगाना': ('v', 0.0, 0.0),
#  'बहारना': ('v', 0.0, 0.0),
#  'हिटलर': ('v', 0.0, 0.0),
#  'एडोल्फ_हिटलर': ('v', 0.0, 0.0),
#  'कोलाहल': ('n', 0.0, 0.0),
#  'शोरग़ुल': ('n', 0.0, 0.0),
#  'शोरगुल': ('n', 0.0, 0.0),
#  'शोरशराबा': ('n', 0.0, 0.0),
#  'शोर-शराबा': ('n', 0.0, 0.0),
#  'हल्लागुल्ला': ('n', 0.0, 0.0),
#  'हल्ला-गुल्ला': ('n', 0.0, 0.0),
#  'शोर': ('n', 0.0, 0.0),
#  'हंगामा': ('n', 0.0, 0.0),
#  'हल्ला': ('n', 0.0, 0.0),
#  'खलबल': ('n', 0.0, 0.0),
#  'खल-बल': ('n', 0.0, 0.0),
#  'चिल्लमचिल्ला': ('n', 0.0, 0.0),
#  'सोर': ('n', 0.0, 0.0),
#  'चिल्लपों': ('n', 0.0, 0.0),
#  'चिल्लपौं': ('n', 0.0, 0.0),
#  'आघात': ('n', 0.0, 0.0),
#  'चोट': ('n', 0.0, 0.0),
#  'वार': ('n', 0.0, 0.0),
#  'प्रहार': ('n', 0.0, 0.0),
#  'व्याघात': ('n', 0.0, 0.0),
#  'अभिघात': ('n', 0.0, 0.0),
#  'मथना': ('v', 0.0, 0.0),
#  'बिलोना': ('v', 0.0, 0.0),
#  'मंथन_करना': ('v', 0.0, 0.0),
#  'बिलोड़ना': ('v', 0.0, 0.0),
#  'गाहना': ('v', 0.0, 0.0),
#  'काँपना': ('v', 0.25, 0.0),
#  'कँपना': ('v', 0.0, 0.0),
#  'कंपित_होना': ('v', 0.25, 0.0),
#  'कंपन_होना': ('v', 0.25, 0.0),
#  'थरथराना': ('v', 0.25, 0.0),
#  'सिहरना': ('v', 0.0, 0.0),
#  'थर-थर_करना': ('v', 0.0, 0.0),
#  'थरथर_करना': ('v', 0.0, 0.0),
#  'चाटना': ('v', 0.0, 0.0),
#  'भाषण_देना': ('v', 0.0, 0.0),
#  'बोलना': ('v', 0.0, 0.0),
#  'वक्तव्य_देना': ('v', 0.0, 0.0),
#  'करना': ('n', 0.0, 0.0),
#  'रेताना': ('v', 0.0, 0.0),
#  'कटना': ('v', 0.0, 0.0),
#  'गड़ाना': ('v', 0.0, 0.0),
#  'चुभाना': ('v', 0.0, 0.0),
#  'सालना': ('v', 0.0, 0.0),
#  'कोंचना': ('v', 0.0, 0.0),
#  'गड़ोना': ('v', 0.0, 0.0),
#  'काटना': ('v', 0.0, 0.0),
#  'कुतरना': ('v', 0.0, 0.0),
#  'घुमाना': ('v', 0.0, 0.0),
#  'घुमा_देना': ('v', 0.0, 0.0),
#  'मोड़ना': ('v', 0.0, 0.0),
#  'मोड़_देना': ('v', 0.0, 0.0),
#  'खींचना': ('v', 0.0, 0.0),
#  'खीचना': ('v', 0.0, 0.0),
#  'घसीटना': ('v', 0.0, 0.0),
#  'घिसटना': ('v', 0.0, 0.0),
#  'लहराना': ('v', 0.0, 0.0),
#  'फहराना': ('v', 0.0, 0.0),
#  'फरफराना': ('v', 0.0, 0.0),
#  'उड़ाना': ('v', 0.0, 0.0),
#  'बिछुड़ना': ('v', 0.0, 0.0),
#  'बिलगना': ('v', 0.0, 0.0),
#  'छूटना': ('v', 0.0, 0.0),
#  'छूट_जाना': ('v', 0.0, 0.0),
#  'विलग_होना': ('v', 0.0, 0.0),
#  'अलग_होना': ('v', 0.0, 0.0),
#  'टाँगना': ('v', 0.0, 0.0),
#  'टांगना': ('v', 0.0, 0.0),
#  'लटकाना': ('v', 0.0, 0.0),
#  'लटकना': ('v', 0.0, 0.0),
#  'झूलना': ('v', 0.0, 0.0),
#  'बंडल': ('v', 0.0, 0.0),
#  'गाँठ': ('n', 0.0, 0.0),
#  'पुलिंदा': ('v', 0.0, 0.0),
#  'काम_करना': ('n', 0.0, 0.0),
#  'कार्य_करना': ('n', 0.0, 0.0),
#  'जुआ': ('n', 0.0, 0.0),
#  'जूआ': ('n', 0.0, 0.0),
#  'जुआठ': ('n', 0.0, 0.0),
#  'जुआठा': ('n', 0.0, 0.0),
#  'युग': ('n', 0.0, 0.0),
#  'जूड़': ('n', 0.0, 0.0),
#  'माची': ('n', 0.0, 0.0),
#  'कुश्ती': ('v', 0.0, 0.0),
#  'मल्ल_युद्ध': ('n', 0.0, 0.0),
#  'मल्लयुद्ध': ('v', 0.0, 0.0),
#  'लड़ाई': ('n', 0.0, 0.0),
#  'संघर्ष': ('n', 0.0, 0.0),
#  'जंग': ('n', 0.0, 0.0),
#  'द्वंद्व': ('n', 0.0, 0.0),
#  'द्वन्द्व': ('n', 0.0, 0.0),
#  'फेंकना': ('n', 0.0, 0.0),
#  'अधिक्षेपण': ('v', 0.0, 0.0),
#  'अधिक्षेप': ('n', 0.0, 0.25),
#  'तानना': ('v', 0.0, 0.0),
#  'घूमना': ('v', 0.0, 0.0),
#  'चक्कर_खाना': ('v', 0.0, 0.0),
#  'घूर्णित_होना': ('v', 0.0, 0.0),
#  'नाचना': ('v', 0.0, 0.0),
#  'धागा': ('v', 0.0, 0.0),
#  'तागा': ('v', 0.0, 0.0),
#  'सूत': ('n', 0.0, 0.0),
#  'डोरा': ('v', 0.0, 0.0),
#  'डोर': ('v', 0.0, 0.0),
#  'सूता': ('v', 0.0, 0.0),
#  'सूत्र': ('a', 0.0, 0.375),
#  'तन्तु': ('n', 0.0, 0.0),
#  'तंतु': ('n', 0.0, 0.0),
#  'तंत्र': ('v', 0.0, 0.0),
#  'चाबी_देना': ('v', 0.0, 0.0),
#  'कूकना': ('v', 0.0, 0.0),
#  'छापना': ('v', 0.0, 0.0),
#  'छुड़ाना': ('v', 0.0, 0.125),
#  'छोड़ाना': ('v', 0.0, 0.125),
#  'धोना': ('v', 0.0, 0.0),
#  'फींचना': ('v', 0.0, 0.0),
#  'छाँटना': ('v', 0.0, 0.0),
#  'खड़ा_होना': ('v', 0.0, 0.0),
#  'उठना': ('a', 0.0, 0.0),
#  'वृद्धि': ('n', 0.0, 0.0),
#  'बढ़ती': ('n', 0.0, 0.0),
#  'बढ़ोतरी': ('n', 0.0, 0.0),
#  'बढ़त': ('n', 0.0, 0.0),
#  'प्रवर्धन': ('n', 0.0, 0.0),
#  'प्रवर्द्धन': ('n', 0.0, 0.0),
#  'चढ़ाव': ('n', 0.0, 0.0),
#  'इज़ाफ़ा': ('n', 0.0, 0.0),
#  'इजाफा': ('n', 0.0, 0.0),
#  'अभिवृद्धि': ('n', 0.0, 0.0),
#  'चीरा': ('v', 0.0, 0.0),
#  'उत्कीर्ण_करना': ('v', 0.0, 0.0),
#  'खोदना': ('v', 0.0, 0.0),
#  'उकेरना': ('v', 0.0, 0.0),
#  'चुन्नी': ('n', 0.0, 0.0),
#  'चुनी': ('n', 0.0, 0.0),
#  'उन्मुक्त': ('a', 0.0, 0.75),
#  'आज़ाद': ('a', 0.0, 0.75),
#  'आजाद': ('a', 0.0, 0.75),
#  'खुला': ('a', 0.25, 0.375),
#  'बंधनमुक्त': ('a', 0.0, 0.75),
#  'मुक्त': ('a', 0.0, 0.75),
#  'अजाद': ('a', 0.0, 0.75),
#  'अनिबद्ध': ('a', 0.0, 0.75),
#  'मुंच': ('a', 0.0, 0.75),
#  'बन्धनमुक्त': ('a', 0.0, 0.75),
#  'अबद्ध': ('a', 0.0, 0.625),
#  'वीत': ('a', 0.0, 0.75),
#  'जीतना': ('v', 0.0, 0.0),
#  'विजय_पाना': ('v', 0.0, 0.0),
#  'विजयी_होना': ('v', 0.0, 0.0),
#  'लगाना': ('v', 0.0, 0.0),
#  'जमाना': ('v', 0.0, 0.0),
#  'रोपना': ('v', 0.0, 0.0),
#  'जकड़ना': ('v', 0.0, 0.0),
#  'कृतज्ञ': ('v', 0.0, 0.125),
#  'एहसानमंद': ('v', 0.0, 0.125),
#  'अहसानमंद': ('v', 0.0, 0.125),
#  'आभारी': ('v', 0.0, 0.125),
#  'शुक्रगुज़ार': ('v', 0.0, 0.125),
#  'शुक्रगुजार': ('v', 0.0, 0.125),
#  'उपकृत': ('v', 0.0, 0.125),
#  'अनुगृहीत': ('v', 0.0, 0.125),
#  'भिड़ना': ('v', 0.0, 0.0),
#  'पिलना': ('v', 0.0, 0.0),
#  'भिगोना': ('v', 0.0, 0.0),
#  'भिगाना': ('v', 0.0, 0.0),
#  'भिंगाना': ('v', 0.0, 0.0),
#  'भिजाना': ('v', 0.0, 0.0),
#  'भिंजाना': ('v', 0.0, 0.0),
#  'मुड़ना': ('v', 0.0, 0.0),
#  'निर्णीत': ('a', 0.0, 0.125),
#  'निर्णित': ('a', 0.0, 0.125),
#  'निपटा_हुआ': ('r', 0.0, 0.125),
#  'तय': ('a', 0.0, 0.125),
#  'तयशुदा': ('a', 0.0, 0.125),
#  'घिरना': ('v', 0.375, 0.0),
#  'घेराना': ('v', 0.375, 0.0),
#  'बेआराम': ('r', 0.0, 0.0),
#  'बिछाना': ('a', 0.0, 0.0),
#  'डालना': ('a', 0.0, 0.0),
#  'बोझ': ('n', 0.125, 0.0),
#  'भार': ('n', 0.125, 0.0),
#  'काँटा': ('n', 0.0, 0.0),
#  'कांटा': ('n', 0.0, 0.0),
#  'बजाज': ('v', 0.0, 0.0),
#  'बज़्ज़ाज़': ('v', 0.0, 0.0),
#  'बज़ाज़': ('v', 0.0, 0.0),
#  'उजाड़ना': ('v', 0.0, 0.25),
#  'उजाड़_देना': ('v', 0.0, 0.25),
#  'नष्ट_करना': ('n', 0.0, 0.0),
#  'ख़ाक_करना': ('v', 0.0, 0.25),
#  'नाश_करना': ('v', 0.0, 0.25),
#  'मिटाना': ('v', 0.0, 0.0),
#  'चौपट_करना': ('v', 0.0, 0.25),
#  'मारना': ('n', 0.0, 0.0),
#  'पीटना': ('v', 0.25, 0.0),
#  'प्रहार_करना': ('v', 0.25, 0.0),
#  'ठोंकना': ('v', 0.25, 0.0),
#  'ठोकना': ('v', 0.25, 0.0),
#  'पीटाई_करना': ('v', 0.25, 0.0),
#  'धुनना': ('v', 0.25, 0.0),
#  'धुनाई_करना': ('v', 0.25, 0.0),
#  'ताड़ना': ('n', 0.0, 0.0),
#  'प्रताड़ना': ('n', 0.0, 0.0),
#  'रसीद_करना': ('v', 0.25, 0.0),
#  'निकालना': ('v', 0.0, 0.0),
#  'आविष्कार_करना': ('v', 0.0, 0.0),
#  'खोज_निकालना': ('v', 0.0, 0.0),
#  'ईज़ाद_करना': ('v', 0.0, 0.0),
#  'ईजाद_करना': ('v', 0.0, 0.0),
#  'आविष्कृत_करना': ('v', 0.0, 0.0),
#  'कहना': ('v', 0.0, 0.0),
#  'बदना': ('v', 0.0, 0.0),
#  'छक्का': ('n', 0.0, 0.0),
#  'रजाई': ('v', 0.0, 0.0),
#  'रज़ाई': ('v', 0.0, 0.0),
#  'लिहाफ': ('v', 0.0, 0.0),
#  'लिहाफ़': ('v', 0.0, 0.0),
#  'बुनना': ('v', 0.0, 0.0),
#  'बीनना': ('v', 0.0, 0.0),
#  'बिनना': ('v', 0.0, 0.0),
#  'बुनाई_करना': ('v', 0.0, 0.0),
#  'गोदना': ('v', 0.0, 0.0),
#  'गढ़ना': ('v', 0.0, 0.0),
#  'बनाना': ('v', 0.0, 0.0),
#  'सरजना': ('v', 0.0, 0.0),
#  'सिरजना': ('v', 0.0, 0.0),
#  'आकार_देना': ('v', 0.0, 0.0),
#  'रूप_देना': ('v', 0.0, 0.0),
#  'रचना': ('n', 0.125, 0.0),
#  'लिखना': ('v', 0.0, 0.0),
#  'प्रतिरूप_बनाना': ('v', 0.0, 0.0),
#  'नकल_करना': ('v', 0.0, 0.0),
#  'नक़ल_करना': ('v', 0.0, 0.0),
#  'सुनाना': ('v', 0.0, 0.0),
#  'फिल्म': ('v', 0.0, 0.0),
#  'अभिनय_करना': ('v', 0.0, 0.0),
#  'रोल_करना': ('v', 0.0, 0.0),
#  'खिलौना': ('v', 0.0, 0.0),
#  'खेलवाड़': ('n', 0.75, 0.0),
#  'खिलवाड़': ('n', 0.75, 0.0),
#  'एकमात्र': ('v', 0.0, 0.0),
#  'एकलौता': ('v', 0.0, 0.0),
#  'इकलौता': ('v', 0.0, 0.0),
#  'उन्नत': ('a', 0.375, 0.0),
#  'प्रोन्नत': ('a', 0.375, 0.0),
#  'विकसित': ('a', 0.375, 0.0),
#  'सुविकसित': ('a', 0.375, 0.0),
#  'प्रकाशित_करना': ('v', 0.0, 0.0),
#  'छपना': ('v', 0.0, 0.0),
#  'मुद्रित_होना': ('v', 0.0, 0.0),
#  'पक्षीय': ('a', 0.0, 0.0),
#  'खगीय': ('a', 0.0, 0.0),
#  'पक्षी_संबंधी': ('a', 0.0, 0.0),
#  'विहंगी': ('a', 0.0, 0.0),
#  'विहंगीय': ('a', 0.0, 0.0),
#  'अजरबैजानी': ('a', 0.0, 0.0),
#  'अज़रबैजानी': ('a', 0.0, 0.0),
#  'अजरबैजान_वासी': ('a', 0.0, 0.0),
#  'अज़रबैजान_वासी': ('a', 0.0, 0.0),
#  'अजरबैजान-वासी': ('a', 0.0, 0.0),
#  'अज़रबैजान-वासी': ('a', 0.0, 0.0),
#  'प्रति': ('n', 0.0, 0.0),
#  'कापी': ('n', 0.0, 0.0),
#  'कॉपी': ('n', 0.0, 0.0),
#  'तैयार_करना': ('v', 0.0, 0.0),
#  'निर्माण_करना': ('v', 0.0, 0.0),
#  'जलाना': ('v', 0.375, 0.125),
#  'प्रज्वलित_करना': ('v', 0.375, 0.125),
#  'लुब्ध_होना': ('v', 0.25, 0.0),
#  'लुभना': ('v', 0.25, 0.0),
#  'मन_डोलना': ('v', 0.25, 0.0),
#  'ओसाई': ('v', 0.0, 0.0),
#  'गाहाई': ('v', 0.0, 0.0),
#  'डाली': ('v', 0.0, 0.0),
#  'पड़ना': ('v', 0.25, 0.25),
#  'खीज': ('v', 0.0, 0.5),
#  'झुँझलाहट': ('v', 0.0, 0.5),
#  'कुढ़न': ('v', 0.0, 0.5),
#  'भँड़ास': ('v', 0.0, 0.5),
#  'खुंदक': ('v', 0.0, 0.5),
#  'खीस': ('v', 0.0, 0.5),
#  'अनख': ('v', 0.0, 0.5),
#  'प्रभावित_करना': ('v', 0.125, 0.125),
#  'प्रभाव_डालना': ('v', 0.125, 0.125),
#  'असर_करना': ('v', 0.125, 0.125),
#  'रंग_जमाना': ('v', 0.125, 0.125),
#  'रंगना': ('v', 0.125, 0.125),
#  'छाना': ('v', 0.125, 0.125),
#  'प्रेम': ('v', 0.375, 0.125),
#  'अनुराग': ('v', 0.375, 0.125),
#  'प्यार': ('v', 0.375, 0.125),
#  'मुहब्बत': ('v', 0.375, 0.125),
#  'इश्क़': ('v', 0.375, 0.125),
#  'इश्क': ('v', 0.375, 0.125),
#  'लगन': ('v', 0.375, 0.125),
#  'प्रीति': ('v', 0.375, 0.125),
#  'अनुरंजन': ('v', 0.375, 0.125),
#  'अनुरन्जन': ('v', 0.375, 0.125),
#  'राग': ('v', 0.375, 0.125),
#  'जैसा': ('v', 0.5, 0.25),
#  'सरिखा': ('v', 0.5, 0.25),
#  'जस': ('v', 0.5, 0.25),
#  'अनुष्ठान': ('n', 0.125, 0.0),
#  'भय': ('v', 0.125, 0.625),
#  'खौफ': ('v', 0.125, 0.625),
#  'ख़ौफ़': ('v', 0.125, 0.625),
#  'डर': ('v', 0.125, 0.625),
#  'त्रास': ('v', 0.125, 0.625),
#  'भीति': ('v', 0.125, 0.625),
#  'संत्रास': ('v', 0.125, 0.625),
#  'अपभय': ('v', 0.125, 0.625),
#  'दहशत': ('v', 0.125, 0.625),
#  'भयभीत': ('n', 0.0, 0.0),
#  'डरा_हुआ': ('n', 0.0, 0.0),
#  'डरा': ('n', 0.0, 0.0),
#  'कातर': ('n', 0.0, 0.0),
#  'आतंकित': ('n', 0.0, 0.0),
#  'ख़ौफ़ज़द': ('n', 0.0, 0.0),
#  'भयग्रस्त': ('n', 0.0, 0.0),
#  'भयान्वित': ('n', 0.0, 0.0),
#  'भीत': ('n', 0.0, 0.0),
#  'अपत्रस्त': ('n', 0.0, 0.0),
#  'दहशतज़दा': ('n', 0.0, 0.0),
#  'दहशतजदा': ('n', 0.0, 0.0),
#  'सकपकाना': ('v', 0.0, 0.125),
#  'चकपकाना': ('v', 0.0, 0.125),
#  'भौंचक्का_होना': ('v', 0.0, 0.125),
#  'भौचक्का_होना': ('v', 0.0, 0.125),
#  'चौंकना': ('v', 0.0, 0.125),
#  'दाँना': ('v', 0.0, 0.0),
#  'दाना': ('v', 0.0, 0.0),
#  'दांवना': ('v', 0.0, 0.0),
#  'दांना': ('v', 0.0, 0.0),
#  'दाँवना': ('v', 0.0, 0.0),
#  'मरना': ('v', 0.0, 0.0),
#  'क्रोध': ('v', 0.0, 0.0),
#  'गुस्सा': ('v', 0.0, 0.0),
#  'आक्रोश': ('v', 0.0, 0.0),
#  'कोप': ('v', 0.0, 0.0),
#  'रोष': ('v', 0.0, 0.0),
#  'खुन्नस': ('v', 0.0, 0.0),
#  ...}

# %%
#function to find the sentiment of the input text parameter
def sentiment(text):
    words = word_tokenize(text)
    votes = []
    pos_polarity = 0
    neg_polarity = 0
    allowed_words = ['a','v','r','n']
    for word in words:
        if word in words_dict:
            #if word in dictionary, it picks up the positive and negative score of the word
            pos_tag, pos, neg = words_dict[word]
            if pos_tag in allowed_words:
                if pos > neg:
                    pos_polarity += pos
                    votes.append(1)
                elif neg > pos:
                    neg_polarity += neg
                    votes.append(0)
    #calculating the no. of positive and negative words in total
    pos_votes = votes.count(1)
    neg_votes = votes.count(0)
    if pos_votes > neg_votes:
        return 1
    elif neg_votes > pos_votes:
        return -1
    else:
        if pos_polarity < neg_polarity:
            return -1
        elif pos_polarity > neg_polarity:
            return 1
        else:
            return 1

# %%
temp["HSWN_sentiment"] = temp["hin_cleaned"].apply(lambda x: sentiment(x))

# %%
temp['HSWN_sentiment'].value_counts()
# Out:
#  1    732
# -1    318
# Name: HSWN_sentiment, dtype: int64

# %%
temp['polarity'].value_counts()
# Out:
#  1    587
# -1    463
# Name: polarity, dtype: int64

# %% [markdown]
# # Finding accuracy

# %%
accuracy = accuracy_score(temp["HSWN_sentiment"], temp["polarity"])

# %%
accuracy
# Out:
# 0.5361904761904762
